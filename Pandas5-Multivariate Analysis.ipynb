# %% [markdown]
# ![image.png](attachment:5ff7a089-98ce-4a3e-8e72-4108475eef51.png)

# %% [raw]
# There are several different multivariate analysis methods that can be used in Exploratory Data Analysis (EDA). These include:
#
# Factor Analysis: Scikit-Learn
# Principal Component Analysis (PCA): Scikit-Learn
# Cluster Analysis: Scikit-Learn
# Discriminant Analysis: Scikit-Learn
# Multidimensional Scaling: Scikit-Learn
# Correspondence Analysis: Scikit-Learn, Statsmodels
# Canonical Correlation: Scikit-Learn
# Structural Equation Modeling: Statsmodels
# Multivariate Adaptive Regression Splines (MARS): Scikit-Learn
# Multivariate Regression: Scikit-Learn
# Multivariate Time Series Analysis: Scikit-Learn, Statsmodels
# Multivariate Analysis of Variance (MANOVA): Scikit-Learn
# Star Plots: Matplotlib
# Biplots: Matplotlib

# %% [raw]
# but there are just few methods that relies  just on pandas library:
#
# corr() to calculate the correlation matrix
# cov() to calculate the covariance matrix
#
# factorplot() to create a factor plot
# heatmap() to create a heatmap
# scatter_matrix() to create a matrix of scatter plots
# pairplot() to create a pairwise plot of variables
# boxplot() to create a boxplot
# lmplot() to create a linear model plot
# violinplot() to create a violin plot
# radviz() to create a radial visualisation plot
# parallel_coordinates() to create a parallel coordinates plot
# clustermap() to create a hierarchical clustering plot
