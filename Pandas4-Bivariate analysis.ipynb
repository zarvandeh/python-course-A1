# %% [markdown]
# ![image.png](attachment:49dac117-e7e3-4335-878f-37fbd9872188.png)

# %% [raw]
# df.corr() – To calculate the correlation coefficient of all numeric columns.
# df.cov() – To calculate the covariance of all numeric columns.
# df.pct_change() – To calculate the percent change of all numeric columns.
# df.diff() – To calculate the difference between all numeric columns.
# df.shift() – To shift the values of all numeric columns.
# df.rolling() – To calculate the rolling statistic of all numeric columns.
# df.expanding() – To calculate the expanding statistic of all numeric columns.
# df.groupby() – To group the data based on a certain criterion.
# df.plot() – To visualize the data using charts and graphs.
# df.scatter() – To plot a scatter plot of two columns.
# df.regplot() – To plot a regression line of two columns.
# df.boxplot() – To plot a boxplot of two columns.
# df.heatmap() – To plot a heatmap of two columns.
# df.pairplot() – To plot the pairwise relationships of all columns.
# df.corrplot() – To plot the correlation matrix of all columns.

# %% [markdown]
# ##### note that not all bivariate analysis methods can be conducted just using pandas dataframes

# %% [markdown]
# ![image.png](attachment:39affdf8-7cab-45d8-9268-c419474c48ec.png)
