# %% [markdown]
# ![image.png](attachment:eb5124d2-7e85-407d-b646-04313bd708f1.png)

# %% [markdown]
# # Define the research question and gather data.
# 1. importing data and investigating it

# %% [raw]
# pandas.read_csv()
# pandas.read_excel()
# pandas.read_sql()

# %% [markdown]
# ##### investigation of the data

# %% [raw]
# pandas.isnull().sum()
# pandas.duplicated().sum()
# pandas.head()
# pandas.tail()
# pandas.shape
# pandas.info()
# pandas.describe()
# df.nunique() – To calculate the number of unique values in each column.
# df.value_counts() – To calculate the number of occurrences of each value in a column.
# df.quantile() – To calculate the quantiles of all numeric columns.
# df.sort_values() – To sort the data based on the values in a column.

# %% [markdown]
# ##### Slice the data and get desired dataset

# %% [raw]
# loc(): Selects elements from a DataFrame based on labels or a boolean array.
# iloc(): Selects elements from a DataFrame based on integer positions.
# at(): Selects a single element from a DataFrame.
# iat(): Selects a single element from a DataFrame by integer position.
# query(): Selects elements from a DataFrame based on a query expression.

# %% [markdown]
# ##### sorting values

# %% [raw]
# df.sort_index() – To sort the data based on the row or column labels.
# df.sort() – To sort by the values in multiple columns.
# df.sort_values(by='colname',ascending=False) – To sort the data in descending order.

# %% [raw]
# df.sortvalues(by, axis=0, ascending=True, inplace=False, kind='quicksort', naposition='last')

# %% [raw]
# Kind	Description
# quicksort	The default sorting algorithm. A fast sorting algorithm that is not stable.
# mergesort	A stable sorting algorithm that is slower than quicksort.
# heapsort	A stable sorting algorithm that is slower than quicksort.

# %% [markdown]
# # Lets start collecting data

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('vgames.csv')

# %%
##### investigation of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### make our filters

# %%
#see Genre of games

# %%
df.Genre.value_counts()
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
#get all action games

# %%
actions=df[df.Genre=='Action']

# %%
#which companies are making action games?

# %%
actions.Publisher.value_counts()
# Out:
# Activision            311
# Namco Bandai Games    251
# Ubisoft               198
# THQ                   194
# Electronic Arts       183
#                      ...
# Crytek                  1
# Telstar                 1
# SCS Software            1
# Black Bean Games        1
# Red Flagship            1
# Name: Publisher, Length: 235, dtype: int64

# %%
# show only action games from Ubisoft

# %%
ubiactions=df[(df.Genre=='Action')&(df.Publisher=='Ubisoft')]

# %%
ubiactions.head(3)
# Out:
#                      Name Platform  Year_of_Release   Genre Publisher  \
# 127  Assassin's Creed III      PS3           2012.0  Action   Ubisoft
# 159   Assassin's Creed II      PS3           2009.0  Action   Ubisoft
# 176  Assassin's Creed III     X360           2012.0  Action   Ubisoft
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 127      2.64      2.52      0.16         1.12          6.45          85.0
# 159      2.54      1.93      0.21         0.86          5.55          91.0
# 176      3.13      1.69      0.03         0.44          5.29          84.0
#
#      Critic_Count  User_Score  User_Count         Developer Rating
# 127          41.0         6.9      1307.0           Ubisoft      M
# 159          70.0         8.6      1202.0  Ubisoft Montreal      M
# 176          61.0         6.7      1196.0           Ubisoft      M

# %%
ubiactions.tail(3)
# Out:
#                                  Name Platform  Year_of_Release   Genre  \
# 16471  Crouching Tiger, Hidden Dragon       XB           2003.0  Action
# 16548     Assassin's Creed Chronicles     XOne           2016.0  Action
# 16649                          ZombiU     XOne           2016.0  Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16471   Ubisoft      0.01      0.00       0.0          0.0          0.01
# 16548   Ubisoft      0.00      0.01       0.0          0.0          0.01
# 16649   Ubisoft      0.00      0.01       0.0          0.0          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count       Developer  \
# 16471          52.0          10.0         NaN         NaN           Genki
# 16548           NaN           NaN         6.8         8.0  Climax Studios
# 16649           NaN           NaN         NaN         NaN             NaN
#
#       Rating
# 16471      T
# 16548      T
# 16649    NaN

# %%
ubiactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 127 to 16649
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             198 non-null    object
#  1   Platform         198 non-null    object
#  2   Year_of_Release  198 non-null    float64
#  3   Genre            198 non-null    object
#  4   Publisher        198 non-null    object
#  5   NA_Sales         198 non-null    float64
#  6   EU_Sales         198 non-null    float64
#  7   JP_Sales         198 non-null    float64
#  8   Other_Sales      198 non-null    float64
#  9   Global_Sales     198 non-null    float64
#  10  Critic_Score     165 non-null    float64
#  11  Critic_Count     165 non-null    float64
#  12  User_Score       162 non-null    float64
#  13  User_Count       162 non-null    float64
#  14  Developer        179 non-null    object
#  15  Rating           176 non-null    object
# ...

# %%
ubiactions.describe()
# Out:
#        Year_of_Release    NA_Sales    EU_Sales    JP_Sales  Other_Sales  \
# count       198.000000  198.000000  198.000000  198.000000   198.000000
# mean       2008.838384    0.352929    0.276111    0.010707     0.085505
# std           4.450990    0.574071    0.458421    0.029263     0.159280
# min        1998.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2005.000000    0.052500    0.020000    0.000000     0.010000
# 50%        2009.000000    0.140000    0.075000    0.000000     0.020000
# 75%        2012.750000    0.360000    0.340000    0.000000     0.090000
# max        2016.000000    3.130000    2.520000    0.210000     1.120000
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score   User_Count
# count    198.000000    165.000000    165.000000  162.000000   162.000000
# mean       0.726010     71.157576     30.133333    6.957407   282.148148
# std        1.147268     13.911721     20.938800    1.405217   520.229001
# ...

# %%
ubiactions.Platform.nunique()
# Out:
# 17

# %%
ubiactions.Platform.value_counts()
# Out:
# X360    25
# PC      23
# PS3     21
# GBA     16
# DS      14
# PS4     13
# XOne    13
# PS2     13
# XB      12
# GC      10
# PSP     10
# Wii      9
# WiiU     8
# PSV      4
# 3DS      3
# PS       2
# N64      2
# Name: Platform, dtype: int64

# %%
ubiactions.sort_values(by=['Year_of_Release','User_Score'],ascending=False)
# Out:
#                                      Name Platform  Year_of_Release   Genre  \
# 12157         Assassin's Creed Chronicles      PSV           2016.0  Action
# 5338                     TrackMania Turbo      PS4           2016.0  Action
# 1806                         Watch Dogs 2      PS4           2016.0  Action
# 5230                         Watch Dogs 2     XOne           2016.0  Action
# 12401                    TrackMania Turbo     XOne           2016.0  Action
# ...                                   ...      ...              ...     ...
# 14640                  Planet of the Apes      GBA           2001.0  Action
# 8391   Batman Beyond: Return of the Joker       PS           2000.0  Action
# 7687          Tom and Jerry in House Trap       PS           2000.0  Action
# 11059  Batman Beyond: Return of the Joker      N64           2000.0  Action
# 8583                          Buck Bumble      N64           1998.0  Action
#
# ...

# %% [markdown]
# ##### Slicing data of ubisoft games

# %%
ubis=df[df.Publisher=='Ubisoft']

# %%
ubis.Genre.unique()
# Out:
# array(['Misc', 'Action', 'Adventure', 'Shooter', 'Role-Playing',
#        'Platform', 'Simulation', 'Sports', 'Racing', 'Fighting',
#        'Strategy', 'Puzzle'], dtype=object)

# %%
action_or_sport_data = ubis.query('Year_of_Release > 2012 and Genre == "Action" or Genre == "Shooter"')

# %%
action_or_sport_data.sample(5)
# Out:
#                              Name Platform  Year_of_Release    Genre  \
# 11921  Tom Clancy's Ghost Recon 2       GC           2005.0  Shooter
# 298                     Far Cry 4      PS4           2014.0  Shooter
# 9512                   Watch Dogs     WiiU           2014.0   Action
# 889      Tom Clancy's Ghost Recon      PS2           2002.0  Shooter
# 7726                 Sniper Elite      PS2           2005.0  Shooter
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 11921   Ubisoft      0.06      0.01       0.0         0.00          0.07
# 298     Ubisoft      1.13      2.18       0.1         0.63          4.04
# 9512    Ubisoft      0.07      0.05       0.0         0.01          0.13
# 889     Ubisoft      1.42      0.40       0.0         0.12          1.94
# 7726    Ubisoft      0.10      0.07       0.0         0.02          0.19
#
#        Critic_Score  Critic_Count  User_Score  User_Count         Developer  \
# ...

# %%
bloods=ubis[ubis.Name.str.lower().str.contains('blood')]

# %%
bloods=bloods.reset_index()

# %% [markdown]
# #### using Locator methods

# %% [raw]
# df.loc[rows, columns]

# %%
bloods.loc[ 0:4 , ['Name','Year_of_Release','Platform','Genre','Global_Sales'] ]
# Out:
#                                 Name  Year_of_Release Platform    Genre  \
# 0       Assassin's Creed: Bloodlines           2009.0      PSP   Action
# 1     Call of Juarez: Bound in Blood           2009.0      PS3  Shooter
# 2     Call of Juarez: Bound in Blood           2009.0     X360  Shooter
# 3  Brothers In Arms: Earned in Blood           2005.0      PS2  Shooter
# 4  Brothers In Arms: Earned in Blood           2005.0       XB  Shooter
#
#    Global_Sales
# 0          1.23
# 1          0.88
# 2          0.60
# 3          0.46
# 4          0.31

# %%
bloods.iloc[ 0:4 , 1:8]
# Out:
#                                 Name Platform  Year_of_Release    Genre  \
# 0       Assassin's Creed: Bloodlines      PSP           2009.0   Action
# 1     Call of Juarez: Bound in Blood      PS3           2009.0  Shooter
# 2     Call of Juarez: Bound in Blood     X360           2009.0  Shooter
# 3  Brothers In Arms: Earned in Blood      PS2           2005.0  Shooter
#
#   Publisher  NA_Sales  EU_Sales
# 0   Ubisoft      0.43      0.47
# 1   Ubisoft      0.35      0.37
# 2   Ubisoft      0.30      0.24
# 3   Ubisoft      0.38      0.01

# %%
bloods.iat[1,2]
# Out:
# 'PS3'

# %%
bloods.at[3,'Platform']

# %%
for i in range(10):
    print( f'{df.iat[i,0]} is a game in genre {df.iat[i,3]}' )
# Out:
# Wii Sports is a game in genre Sports
# Super Mario Bros. is a game in genre Platform
# Mario Kart Wii is a game in genre Racing
# Wii Sports Resort is a game in genre Sports
# Pokemon Red/Pokemon Blue is a game in genre Role-Playing
# Tetris is a game in genre Puzzle
# New Super Mario Bros. is a game in genre Platform
# Wii Play is a game in genre Misc
# New Super Mario Bros. Wii is a game in genre Platform
# Duck Hunt is a game in genre Shooter

# %%
#df.query('Name.str.contains("blood")')

# %%
notnullnames=df [ df['Name'].notnull()]
notnullnames.loc[notnullnames['Name'].str.contains('Blood')]
# Out:
#                                          Name Platform  Year_of_Release  \
# 623                                Bloodborne      PS4           2015.0
# 1620             Assassin's Creed: Bloodlines      PSP           2009.0
# 2359           Call of Juarez: Bound in Blood      PS3           2009.0
# 2712   Harry Potter and the Half-Blood Prince      Wii           2009.0
# 2934              James Bond 007: Blood Stone      PS3           2010.0
# ...                                       ...      ...              ...
# 15279             Diabolik Lovers: More Blood      PSV           2015.0
# 15415           Meikyuu Cross Blood: Reloaded     X360           2011.0
# 15704             James Bond 007: Blood Stone       PC           2010.0
# 15743           Blood Bowl: Legendary Edition       PC           2010.0
# 16600                    Unending Bloody Call      PSP           2012.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
