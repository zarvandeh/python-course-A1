# %% [markdown]
# ![image.png](attachment:d05da196-c833-4859-b8c1-a4e56e92681b.png)

# %% [raw]
# df.describe() – To calculate basic statistics for all numeric columns.
# df.count() – To count the number of non-null values in each column.
# df.mean() – To calculate the mean of all numeric columns.
# df.median() – To calculate the median of all numeric columns.
# df.max() – To calculate the maximum of all numeric columns.
# df.min() – To calculate the minimum of all numeric columns.
# df.mode() – To calculate the mode of all numeric columns.
# df.std() – To calculate the standard deviation of all numeric columns.
# df.var() – To calculate the variance of all numeric columns.
# df.skew() – To calculate the skewness of all numeric columns.
# df.kurt() – To calculate the kurtosis of all numeric columns.
# df.quantile() – To calculate the quantile of all numeric columns.
# df.cov() – To calculate the covariance of all numeric columns.
# df.corr() – To calculate the correlation of all numeric columns.
# df.cumsum() – To calculate the cumulative sum of all numeric columns.

# %% [markdown]
# ##### note that not all univariate methods can be conducted just using pandas

# %% [markdown]
# ![image.png](attachment:de2fe601-824d-4a95-92ba-7b35be0e295e.png)
