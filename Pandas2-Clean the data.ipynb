# %% [markdown]
# ![image.png](attachment:6f7a7115-06d7-4372-895a-822528b9bec9.png)

# %% [markdown]
# ![image.png](attachment:b9591fa7-cc6f-4ff6-b249-8695469b4ddb.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## dealing with duplicated data
# DataFrame.duplicated():
#
# DataFrame.duplicated(subset=None, keep='first')

# %% [markdown]
# ![image.png](attachment:4fdae01a-73a3-40c3-b620-93dde5f7ee17.png)

# %% [markdown]
# ##### DataFrame.drop_duplicates(subset=None, keep=’first’) :
#
# Drops duplicate rows from a DataFrame based on a subset of columns and keeping either the first or last occurrence

# %% [markdown]
# ## Dealing with missing data
#
# The most important methods to handle missing data in Pandas are:

# %% [raw]
# DataFrame.dropna(): Drops rows or columns containing missing values.
# DataFrame.fillna(): Replaces missing values with a given value.
# DataFrame.interpolate(): Interpolates missing values using various methods.
# DataFrame.isna(): Returns a Boolean DataFrame indicating the presence of missing values.
# DataFrame.notna(): Returns a Boolean DataFrame indicating the absence of missing values.
# DataFrame.ffill()
# Dataframe.bfill()

# %% [markdown]
# ## Dealing with noisy data sets
# The five most important methods to handle noisy data in Pandas are:

# %% [raw]
# DataFrame.replace(): Replaces values in a DataFrame with another value or set of values.
# DataFrame.astype(): Converts a column of a DataFrame to a specified data type.
# DataFrame.drop(): Drops rows or columns from a DataFrame.
# DataFrame.apply(): Applies a function to each row or column of a DataFrame.
# DataFrame.map(): Maps values of a Series using a mapping specified by a function or a dict.

# %% [markdown]
# ## Dealing with outlier data
#
# most important methods to deal with and remove outliers in Pandas are:

# %% [raw]
# DataFrame.describe(): Generates descriptive statistics of a DataFrame.
# DataFrame.quantile(): Computes the quantile of a given column in a DataFrame.
# DataFrame.clip(): Clips values of a DataFrame using a given lower and upper bound.
# DataFrame.mask(): Replaces values where a condition is met with another value.
# DataFrame.rolling(): Provides rolling window calculations.

# %% [markdown]
# ## Converting data types:
# most important methods to convert data types in Pandas are:

# %% [raw]
# Series.astype(): Converts a Series to a specified data type.
# Series.to_numeric(): Converts a Series to numeric type.
# Series.to_datetime(): Converts a Series to datetime type.
# Series.to_timedelta(): Converts a Series to timedelta type.
# Series.to_period(): Converts a Series to period type.
# Series.to_list(): Converts a Series to a list.
# Series.to_dict(): Converts a Series to a dictionary

# %% [markdown]
# ## Normalizing and restructuring data
#
# most important methods to normalize data in Pandas are:

# %% [markdown]
# ##

# %% [raw]
# DataFrame.apply(): Applies a function to each row or column of a DataFrame.
# DataFrame.transform(): Applies a function to a DataFrame that returns a transformed version of the DataFrame.
# DataFrame.standardize(): Standardizes a DataFrame by subtracting the mean and dividing by the standard deviation.
# DataFrame.normalize(): Normalizes a DataFrame by subtracting the minimum and dividing by the range.
# DataFrame.minmax_scale(): Scales a DataFrame by subtracting the minimum and dividing by the range.
# DataFrame.robust_scale(): Scales a DataFrame by subtracting the median and dividing by the interquartile range.
# Series.rank(): Ranks each element in a Series according to its value.
# Series.quantile(): Computes the quantile of a given column in a Series.
# Series.zscore(): Computes the z-score of each element in a Series.
# Series.scale(): Scales a Series by subtracting the mean and dividing by the standard deviation.

# %% [markdown]
# ## Clean column names

# %% [raw]
# # Get list of column names
# columns = df.columns.values.tolist()
#
# # Strip whitespace
# stripped_columns = [c.strip() for c in columns]
#
# # Replace whitespace with underscores
# cleaned_columns = [c.replace(' ', '_') for c in stripped_columns]
#
# # Set the new column names
# df.columns = cleaned_columns

# %% [markdown]
# ## Working with dummy variables

# %%
# Create a DataFrame with two columns of categorical data
df = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Male'],
    'Country': ['USA', 'USA', 'UK']
})

# Get dummy variables 
dummies = pd.get_dummies(df)

# %%
df
# Out:
#    Gender Country
# 0    Male     USA
# 1  Female     USA
# 2    Male      UK

# %%
dummies
# Out:
#    Gender_Female  Gender_Male  Country_UK  Country_USA
# 0              0            1           0            1
# 1              1            0           0            1
# 2              0            1           1            0

# %% [markdown]
# ## Splitting dataset
#
# There are a variety of methods and code that can be used to split a Pandas DataFrame. Here is a list of 10 such methods and code:

# %% [raw]
# df.groupby()
# df.sample()
# df.query()
# df.filter()
# df.split()
# df.nlargest()
